# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
from sklearn.model_selection import train_test_split
import pathlib

# %%
train_data = pd.read_csv("data/train.csv")
train_data.head()
# Out:
#    VERDICT  PARAMETER_1  PARAMETER_2  PARAMETER_3  PARAMETER_4  PARAMETER_5  \
# 0        1        39353        85475       117961       118300       123472
# 1        1        17183         1540       117961       118343       123125
# 2        1        36724        14457       118219       118220       117884
# 3        1        36135         5396       117961       118343       119993
# 4        1        42680         5905       117929       117930       119569
#
#    PARAMETER_6  PARAMETER_7  PARAMETER_8  PARAMETER_9
# 0       117905       117906       290919       117908
# 1       118536       118536       308574       118539
# 2       117879       267952        19721       117880
# 3       118321       240983       290919       118322
# 4       119323       123932        19793       119325

# %%
test_data = pd.read_csv("data/test.csv")
test_data.head()
# Out:
#    Id  PARAMETER_1  PARAMETER_2  PARAMETER_3  PARAMETER_4  PARAMETER_5  \
# 0   1        78766        72734       118079       118080       117878
# 1   2        40644         4378       117961       118327       118507
# 2   3        75443         2395       117961       118300       119488
# 3   4        43219        19986       117961       118225       118403
# 4   5        42093        50015       117961       118343       119598
#
#    PARAMETER_6  PARAMETER_7  PARAMETER_8  PARAMETER_9
# 0       117879       118177        19721       117880
# 1       118863       122008       118398       118865
# 2       118172       301534       249618       118175
# 3       120773       136187       118960       120774
# 4       118422       300136       118424       118425

# %%
train_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32769 entries, 0 to 32768
# Data columns (total 10 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   VERDICT      32769 non-null  int64
#  1   PARAMETER_1  32769 non-null  int64
#  2   PARAMETER_2  32769 non-null  int64
#  3   PARAMETER_3  32769 non-null  int64
#  4   PARAMETER_4  32769 non-null  int64
#  5   PARAMETER_5  32769 non-null  int64
#  6   PARAMETER_6  32769 non-null  int64
#  7   PARAMETER_7  32769 non-null  int64
#  8   PARAMETER_8  32769 non-null  int64
#  9   PARAMETER_9  32769 non-null  int64
# dtypes: int64(10)
# memory usage: 2.5 MB

# %%
print("Numerical Variables")
numerical_variables = train_data._get_numeric_data().columns
for col in numerical_variables:
    print(col)
# Out:
# Numerical Variables
# VERDICT
# PARAMETER_1
# PARAMETER_2
# PARAMETER_3
# PARAMETER_4
# PARAMETER_5
# PARAMETER_6
# PARAMETER_7
# PARAMETER_8
# PARAMETER_9

# %%
train_data.describe()
# Out:
#             VERDICT    PARAMETER_1    PARAMETER_2    PARAMETER_3  \
# count  32769.000000   32769.000000   32769.000000   32769.000000
# mean       0.942110   42923.916171   25988.957979  116952.627788
# std        0.233539   34173.892702   35928.031650   10875.563591
# min        0.000000       0.000000      25.000000    4292.000000
# 25%        1.000000   20299.000000    4566.000000  117961.000000
# 50%        1.000000   35376.000000   13545.000000  117961.000000
# 75%        1.000000   74189.000000   42034.000000  117961.000000
# max        1.000000  312153.000000  311696.000000  311178.000000
#
#          PARAMETER_4    PARAMETER_5    PARAMETER_6    PARAMETER_7  \
# count   32769.000000   32769.000000   32769.000000   32769.000000
# mean   118301.823156  118912.779914  125916.152644  170178.369648
# std      4551.588572   18961.322917   31036.465825   69509.462130
# min     23779.000000    4674.000000  117879.000000    4673.000000
# 25%    118102.000000  118395.000000  118274.000000  117906.000000
# 50%    118300.000000  118921.000000  118568.000000  128696.000000
# 75%    118386.000000  120535.000000  120006.000000  235280.000000
# max    286791.000000  286792.000000  311867.000000  311867.000000
#
#          PARAMETER_8    PARAMETER_9
# count   32769.000000   32769.000000
# mean   183703.408893  119789.430132
# std    100488.407413    5784.275516
# min      3130.000000  117880.000000
# 25%    118363.000000  118232.000000
# 50%    119006.000000  118570.000000
# 75%    290919.000000  119348.000000
# max    308574.000000  270691.000000

# %%
plt.figure(figsize=(10,7))
i = 0
for ncol in numerical_variables:
    i += 1
    plt.subplot(2,2,i)
    train_data[ncol].value_counts().plot(kind='bar', title=ncol)
plt.tight_layout()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [8], in <cell line: 3>()
#       3 for ncol in numerical_variables:
#       4     i += 1
# ----> 5     plt.subplot(2,2,i)
#       6     train_data[ncol].value_counts().plot(kind='bar', title=ncol)
#       7 plt.tight_layout()
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/matplotlib/pyplot.py:1289, in subplot(*args, **kwargs)
#    1286 fig = gcf()
#    1288 # First, search for an existing subplot with a matching spec.
# -> 1289 key = SubplotSpec._from_subplot_args(fig, args)
#    1291 for ax in fig.axes:
#    1292     # if we found an axes at the position sort out if we can re-use it
#    1293     if hasattr(ax, 'get_subplotspec') and ax.get_subplotspec() == key:
#    1294         # if the user passed no kwargs, re-use
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/matplotlib/gridspec.py:608, in SubplotSpec._from_subplot_args(figure, args)
#     606 else:
#     607     if not isinstance(num, Integral) or num < 1 or num > rows*cols:
# --> 608         raise ValueError(
#     609             f"num must be 1 <= num <= {rows*cols}, not {num!r}")
#     610     i = j = num
#     611 return gs[i-1:j]
#
# ValueError: num must be 1 <= num <= 4, not 5
